# %%
import pandas as pd

# %%
houses = pd.read_csv("data/kc_house_data.csv")
titanic = pd.read_csv("data/titanic.csv")
netflix = pd.read_csv("data/netflix_titles.csv", sep="|", index_col=0)
btc = pd.read_csv("data/coin_Bitcoin.csv")
countries = pd.read_csv("data/world-happiness-report-2021.csv", index_col=0)

# %%
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
# renaming columns
mapper = {'Regional indicator': 'regional_indicator', 'Ladder score': 'ladder_score'}
countries.rename(columns=mapper, inplace=True)

# %%
countries
# Out:
#               regional_indicator  ladder_score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
# renaming index values
mapper = {'Finland': 'finland'}
countries.rename(index=mapper)
# Out:
#               regional_indicator  ladder_score  \
# Country name
# finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
# replacing values from a column
titanic['sex'].replace('female', 'F', inplace=True)

# %%
titanic
# Out:
#       pclass  survived                                             name   sex  \
# 0          1         1                    Allen, Miss. Elisabeth Walton     F
# 1          1         1                   Allison, Master. Hudson Trevor  male
# 2          1         0                     Allison, Miss. Helen Loraine     F
# 3          1         0             Allison, Mr. Hudson Joshua Creighton  male
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)     F
# ...      ...       ...                                              ...   ...
# 1304       3         0                             Zabour, Miss. Hileni     F
# 1305       3         0                            Zabour, Miss. Thamine     F
# 1306       3         0                        Zakarian, Mr. Mapriededer  male
# 1307       3         0                              Zakarian, Mr. Ortin  male
# 1308       3         0                               Zimmerman, Mr. Leo  male
#
# ...

# %%
titanic['sex'].replace('F', 'female', inplace=True)

# %%
# replacing more than one value at a time
titanic['sex'].replace(['female', 'male'], ['F', 'M'])
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
# to replace something with None you need to put the value inside a list
# 263 None values
titanic['age'].replace(['?'], [None]).value_counts(dropna=False)
# Out:
# age
# None      263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: count, Length: 99, dtype: int64

# %%
titanic['age'].replace(['?'], [None], inplace=True)

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
countries.loc['Brazil']
# Out:
# regional_indicator                            Latin America and Caribbean
# ladder_score                                                         6.33
# Standard error of ladder score                                      0.043
# upperwhisker                                                        6.415
# lowerwhisker                                                        6.245
# Logged GDP per capita                                               9.577
# Social support                                                      0.882
# Healthy life expectancy                                            66.601
# Freedom to make life choices                                        0.804
# Generosity                                                         -0.071
# Perceptions of corruption                                           0.756
# Ladder score in Dystopia                                             2.43
# Explained by: Log GDP per capita                                    1.028
# ...

# %%
countries.loc['Brazil':'Cambodia']
# Out:
#                               regional_indicator  ladder_score  \
# Country name
# Brazil               Latin America and Caribbean         6.330
# Mexico               Latin America and Caribbean         6.317
# Jamaica              Latin America and Caribbean         6.309
# Lithuania             Central and Eastern Europe         6.255
# Cyprus                            Western Europe         6.223
# ...                                          ...           ...
# Ukraine       Commonwealth of Independent States         4.875
# Iraq                Middle East and North Africa         4.854
# Gabon                         Sub-Saharan Africa         4.852
# Burkina Faso                  Sub-Saharan Africa         4.834
# Cambodia                          Southeast Asia         4.830
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Brazil                                 0.043         6.415         6.245
# ...

# %%
# get specific columns from a specific index
countries.loc['Brazil',['Generosity', 'Healthy life expectancy']]
# Out:
# Generosity                 -0.071
# Healthy life expectancy    66.601
# Name: Brazil, dtype: object

# %%
countries.loc[['Brazil', 'Panama', 'Costa Rica'],['Generosity', 'Healthy life expectancy']]
# Out:
#               Generosity  Healthy life expectancy
# Country name
# Brazil            -0.071                   66.601
# Panama            -0.166                   69.652
# Costa Rica        -0.126                   71.400

# %%
countries.loc[['Denmark', 'Norway', 'Sweden'], ['regional_indicator']]
# Out:
#              regional_indicator
# Country name
# Denmark          Western Europe
# Norway           Western Europe
# Sweden           Western Europe

# %%
# we can use this syntax to change column values
# by default it changes the original dataframe
countries.loc[['Denmark', 'Norway', 'Sweden'], ['regional_indicator']] = 'Scandinavia'

# %%
countries.head(10)
# Out:
#                  regional_indicator  ladder_score  \
# Country name
# Finland              Western Europe         7.842
# Denmark                 Scandinavia         7.620
# Switzerland          Western Europe         7.571
# Iceland              Western Europe         7.554
# Netherlands          Western Europe         7.464
# Norway                  Scandinavia         7.392
# Sweden                  Scandinavia         7.363
# Luxembourg           Western Europe         7.324
# New Zealand   North America and ANZ         7.277
# Austria              Western Europe         7.268
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...

# %%
countries.loc['Finland', ['upperwhisker', 'lowerwhisker']] = 'LOL'

# %%
countries
# Out:
#               regional_indicator  ladder_score  \
# Country name
# Finland           Western Europe         7.842
# Denmark              Scandinavia         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score upperwhisker lowerwhisker  \
# Country name
# Finland                                0.032          LOL          LOL
# Denmark                                0.035        7.687        7.552
# Switzerland                            0.036        7.643          7.5
# Iceland                                0.059         7.67        7.438
# ...

# %%
countries.loc[['Finland', 'Denmark', 'Iceland', 'Sweden', 'Norway'], ['regional_indicator', 'is_cold']] = ['Nordic countries', 'yes!']

# %%
countries
# Out:
#               regional_indicator  ladder_score  \
# Country name
# Finland         Nordic countries         7.842
# Denmark         Nordic countries         7.620
# Switzerland       Western Europe         7.571
# Iceland         Nordic countries         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score upperwhisker lowerwhisker  \
# Country name
# Finland                                0.032          LOL          LOL
# Denmark                                0.035        7.687        7.552
# Switzerland                            0.036        7.643          7.5
# Iceland                                0.059         7.67        7.438
# ...

# %%
many_bedrooms = houses['bedrooms'] >= 10
houses.loc[many_bedrooms, ['bedrooms']]
# Out:
#        bedrooms
# 8757         11
# 13314        10
# 15161        10
# 15870        33
# 19254        10

# %%
houses.loc[many_bedrooms, ['bedrooms']] = ['TOO MANY!']

# %%
houses[many_bedrooms]
# Out:
#                id             date      price   bedrooms  bathrooms  \
# 8757   1773100755  20140821T000000   520000.0  TOO MANY!       3.00
# 13314   627300145  20140814T000000  1148000.0  TOO MANY!       5.25
# 15161  5566100170  20141029T000000   650000.0  TOO MANY!       2.00
# 15870  2402100895  20140625T000000   640000.0  TOO MANY!       1.75
# 19254  8812401450  20141229T000000   660000.0  TOO MANY!       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 8757          3000      4960     2.0           0     0  ...      7
# 13314         4590     10920     1.0           0     2  ...      9
# 15161         3610     11914     2.0           0     0  ...      7
# 15870         1620      6000     1.0           0     0  ...      7
# 19254         2920      3745     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# ...

# %%
houses[houses['grade'] > 12]
# Out:
#                id             date      price bedrooms  bathrooms  \
# 4411   2470100110  20140804T000000  5570000.0        5       5.75
# 4811   9831200500  20150304T000000  2479000.0        5       3.75
# 5451   7237501190  20141010T000000  1780000.0        4       3.25
# 6041   1725059316  20141120T000000  2385000.0        4       4.00
# 7035    853200010  20140701T000000  3800000.0        5       5.50
# 7252   6762700020  20141013T000000  7700000.0        6       8.00
# 7907   1068000375  20140923T000000  3200000.0        6       5.00
# 9254   9208900037  20140919T000000  6885000.0        6       7.75
# 10373  3303850390  20141212T000000  2983000.0        5       5.50
# 13411  2426039123  20150130T000000  2415000.0        5       4.75
# 13700  4139900180  20150420T000000  2340000.0        4       2.50
# 14556  2303900035  20140611T000000  2888000.0        5       6.25
# 19017  2303900100  20140911T000000  3800000.0        3       4.25
#
# ...

# %%
high_quality = houses['grade'] > 12
great_view = houses['view'] == 4
houses[high_quality & great_view]
# Out:
#                id             date      price bedrooms  bathrooms  \
# 9254   9208900037  20140919T000000  6885000.0        6       7.75
# 14556  2303900035  20140611T000000  2888000.0        5       6.25
# 19017  2303900100  20140911T000000  3800000.0        3       4.25
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 9254          9890     31374     2.0           0     4  ...     13
# 14556         8670     64033     2.0           0     4  ...     13
# 19017         5510     35000     2.0           0     4  ...     13
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 9254         8860           1030      2001             0    98039  47.6305
# 14556        6120           2550      1965          2003    98177  47.7295
# 19017        4910            600      1997             0    98177  47.7296
#
#           long  sqft_living15  sqft_lot15
# 9254  -122.240           4540       42730
# ...

# %%
houses['luxury_level'] = 'normal'

# %%
houses
# Out:
#                id             date     price bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900.0        3       1.00         1180
# 1      6414100192  20141209T000000  538000.0        3       2.25         2570
# 2      5631500400  20150225T000000  180000.0        2       1.00          770
# 3      2487200875  20141209T000000  604000.0        4       3.00         1960
# 4      1954400510  20150218T000000  510000.0        3       2.00         1680
# ...           ...              ...       ...      ...        ...          ...
# 21608   263000018  20140521T000000  360000.0        3       2.50         1530
# 21609  6600060120  20150223T000000  400000.0        4       2.50         2310
# 21610  1523300141  20140623T000000  402101.0        2       0.75         1020
# 21611   291310100  20150116T000000  400000.0        3       2.50         1600
# 21612  1523300157  20141015T000000  325000.0        2       0.75         1020
#
# ...

# %%
houses.loc[high_quality & great_view, ['luxury_level']] = 'ultra'

# %%
houses[high_quality & great_view]
# Out:
#                id             date      price bedrooms  bathrooms  \
# 9254   9208900037  20140919T000000  6885000.0        6       7.75
# 14556  2303900035  20140611T000000  2888000.0        5       6.25
# 19017  2303900100  20140911T000000  3800000.0        3       4.25
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 9254          9890     31374     2.0           0     4  ...        8860
# 14556         8670     64033     2.0           0     4  ...        6120
# 19017         5510     35000     2.0           0     4  ...        4910
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 9254            1030      2001             0    98039  47.6305 -122.240
# 14556           2550      1965          2003    98177  47.7295 -122.372
# 19017            600      1997             0    98177  47.7296 -122.370
#
#        sqft_living15  sqft_lot15  luxury_level
# 9254            4540       42730         ultra
# ...

# %%
houses['luxury_level'].value_counts()
# Out:
# luxury_level
# normal    21610
# ultra         3
# Name: count, dtype: int64
